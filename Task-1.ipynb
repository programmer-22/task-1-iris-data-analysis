# %%
# import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')
df.head()
# save data into cvs file
df.to_csv('iris.cvs')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Load the dataset using the pandas library.

# %%
# load dataset using pandas
df = pd.read_csv('iris.cvs')

# %% [markdown]
# # Display dataset structure using .shape, .columns, and .head().

# %%
# Display data structure
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'sepal_length', 'sepal_width', 'petal_length',
#        'petal_width', 'species'],
#       dtype='object')

# %% [markdown]
# # Basic Visualizations

# %%
# ScatterPlot
sns.scatterplot(data=df, y='petal_length', x='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_length'>

# %%
sns.boxplot(data=df, y='sepal_length', x='petal_width', hue='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_length'>

# %%
# Histogram
df.hist(bins=15, figsize=(9,7), grid=False)
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'sepal_length'}>],
#        [<Axes: title={'center': 'sepal_width'}>,
#         <Axes: title={'center': 'petal_length'}>],
#        [<Axes: title={'center': 'petal_width'}>, <Axes: >]], dtype=object)
